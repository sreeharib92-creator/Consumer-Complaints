# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt

# %%
df =pd.read_csv("26k-consumer-complaints.csv")
df
# Out:
#        Unnamed: 0  Complaint ID          Product  \
# 0               0       1291006  Debt collection
# 1               1       1290580  Debt collection
# 2               2       1290564         Mortgage
# 3               3       1291615      Credit card
# 4               4       1292165  Debt collection
# ...           ...           ...              ...
# 28151       28151       1178184  Debt collection
# 28152       28152       1178183    Consumer loan
# 28153       28153       1178182         Mortgage
# 28154       28154       1178181      Payday loan
# 28155       28155       1178180  Money transfers
#
#                         Sub-product                                     Issue  \
# 0                               NaN                     Communication tactics
# 1                           Medical     Cont'd attempts collect debt not owed
# 2                      FHA mortgage  Application, originator, mortgage broker
# ...

# %%
df1 = df.drop(["Unnamed: 0", "State", "Date sent to company","Complaint ID","Consumer disputed?" ], axis=1)
df1
# Out:
#                Product                   Sub-product  \
# 0      Debt collection                           NaN
# 1      Debt collection                       Medical
# 2             Mortgage                  FHA mortgage
# 3          Credit card                           NaN
# 4      Debt collection      Non-federal student loan
# ...                ...                           ...
# 28151  Debt collection                           NaN
# 28152    Consumer loan                  Vehicle loan
# 28153         Mortgage   Conventional fixed mortgage
# 28154      Payday loan                           NaN
# 28155  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28156 entries, 0 to 28155
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product           28156 non-null  object
#  1   Sub-product       17582 non-null  object
#  2   Issue             28154 non-null  object
#  3   Sub-issue         13211 non-null  object
#  4   ZIP code          27876 non-null  float64
#  5   Date received     28156 non-null  object
#  6   Company           28156 non-null  object
#  7   Company response  28156 non-null  object
#  8   Timely response?  28156 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.9+ MB

# %%
df2=df1.dropna(subset=["Sub-product","Sub-issue","ZIP code","Issue"])

# %%
df2.isna().sum()
# Out:
# Product             0
# Sub-product         0
# Issue               0
# Sub-issue           0
# ZIP code            0
# Date received       0
# Company             0
# Company response    0
# Timely response?    0
# dtype: int64

# %%
df2.head(2)
# Out:
#            Product               Sub-product  \
# 1  Debt collection                   Medical
# 4  Debt collection  Non-federal student loan
#
#                                    Issue                          Sub-issue  \
# 1  Cont'd attempts collect debt not owed                   Debt is not mine
# 4  Cont'd attempts collect debt not owed  Debt resulted from identity theft
#
#    ZIP code Date received                               Company  \
# 1   77479.0    2015-03-19  Accounts Receivable Consultants Inc.
# 4   43068.0    2015-03-19               Transworld Systems Inc.
#
#           Company response Timely response?  product_le  Sub-product_1
# 1  Closed with explanation              Yes           0              3
# 4              In progress              Yes           0              5

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df2.loc[:, "product_le"] = le.fit_transform(df2["Product"])
df2.loc[:, "Sub-product_1"] = le.fit_transform(df2["Sub-product"])
df2.loc[:, "Issue_1"] = le.fit_transform(df2["Issue"])
df2.loc[:, "Sub-issue_1"] = le.fit_transform(df2["Sub-issue"])
df2.loc[:, "Sub-issue_1"] = le.fit_transform(df2["Sub-issue"])
df2.loc[:, "Company_1"] = le.fit_transform(df2["Company"])
df2.loc[:, "Company_response_1"] = le.fit_transform(df2["Company response"])
df2.loc[:, "Sub-issue_1"] = le.fit_transform(df2["Sub-issue"])











df2.head(5)
# Out:
# C:\Users\nidhin\AppData\Local\Temp\ipykernel_23460\3614154386.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:, "Issue_1"] = le.fit_transform(df2["Issue"])
# C:\Users\nidhin\AppData\Local\Temp\ipykernel_23460\3614154386.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:, "Sub-issue_1"] = le.fit_transform(df2["Sub-issue"])
# C:\Users\nidhin\AppData\Local\Temp\ipykernel_23460\3614154386.py:8: SettingWithCopyWarning:
# ...

# %% [raw]
# df3=df2.drop(["Product","Sub-product","Issue","Sub-issue","Date received","Company","Company response","Timely response?"],axis ="columns")
# df3

# %%
input_df=df3.drop(["Company_response_1"],axis = "columns")
input_df
# Out:
#        ZIP code  product_le  Sub-product_1  Issue_1  Sub-issue_1  Company_1
# 1       77479.0           0              3        1            7         34
# 4       43068.0           0              5        1            8        988
# 5       43068.0           0              7        0            2          8
# 7       95124.0           0              7        0            2          8
# 8        7067.0           0              6        1           10        297
# ...         ...         ...            ...      ...          ...        ...
# 28092   93035.0           0              1        3            0        430
# 28093    1331.0           0              6        1            7        360
# 28094   91510.0           0              1        1           10        195
# 28106   94127.0           0              6        1            8        405
# 28148   48622.0           0              5        2           17        988
#
# [5768 rows x 6 columns]

# %%
target=df3.Company_response_1
target
# Out:
# 1        1
# 4        4
# 5        4
# 7        1
# 8        3
#         ..
# 28092    2
# 28093    3
# 28094    1
# 28106    1
# 28148    1
# Name: Company_response_1, Length: 5768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(input_df, target, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1, ..., 3, 3, 1])

# %%
model.score(X_train,y_train)
# Out:
# 0.99913307325531

# %%
model.score(X_test,y_test)
# Out:
# 0.7261698440207972
